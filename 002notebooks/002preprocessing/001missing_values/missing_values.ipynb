# %% [markdown]
# ## Missing values

# %%
import pandas as pd
import numpy as np

# %%
diamonds = pd.read_csv('../../../001data/001adquisition/diamonds_train.csv')
diamonds
# Out:
#        Unnamed: 0                                           index_id  \
# 0               0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1               1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2               2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3               3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4               4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...           ...                                                ...
# 40450       40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...
# 40451       40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...
# 40452       40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...
# 40453       40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...
# 40454       40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...
#
#                                                   cut_id  \
# 0      de88c121a82a06352bf1aaceba20578356408a334ba046...
# ...

# %%
diamonds = diamonds[['price', 'carat', 'depth', 'table', 'x', 'y', 'z', 'cut', 'color', 'clarity', 'city']]

# %%
diamonds.sort_values(by= 'z').head(17)
# Out:
#        price  carat  depth  table     x     y     z      cut color clarity  \
# 24795   3696   1.10   63.0   59.0  6.50  6.47  0.00  Premium     G     SI2
# 34601  15397   2.25   61.3   58.0  8.52  8.42  0.00  Premium     I     SI1
# 14891  12631   2.18   59.4   61.0  8.49  8.45  0.00  Premium     H     SI2
# 19856   3142   1.00   59.1   59.0  6.55  6.48  0.00  Premium     G     SI2
# 26192  18034   2.25   62.8   59.0  0.00  0.00  0.00  Premium     H     SI2
# 16425  17265   2.20   61.2   59.0  8.42  8.37  0.00  Premium     H     SI1
# 28029   2130   0.71   64.1   60.0  0.00  0.00  0.00     Good     F     SI2
# 34423   6381   1.14   57.5   67.0  0.00  0.00  0.00     Fair     G     VS1
# 6465    2130   0.71   64.1   60.0  0.00  0.00  0.00     Good     F     SI2
# 3945   18207   2.02   62.7   53.0  8.02  7.95  0.00  Premium     H     VS2
# 13839  18788   2.80   63.8   58.0  8.90  8.85  0.00     Good     G     SI2
# ...

# %%
#  26192	18034	2.25	62.8	59.0	0.00	0.00	0.00	Premium	H	SI2	Kimberly
diamonds26192 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds26192 = diamonds26192.loc[diamonds26192['color'] == 'H']
diamonds26192 = diamonds26192.loc[diamonds26192['clarity'] == 'SI2']
diamonds26192 = diamonds26192.loc[diamonds26192['carat'] > 2.24]
diamonds26192 = diamonds26192.loc[diamonds26192['carat'] < 2.30]
diamonds26192 = diamonds26192.drop(26192)
diamonds26192.describe()
# Out:
#               price     carat      depth      table         x         y  \
# count      6.000000  6.000000   6.000000   6.000000  6.000000  6.000000
# mean   15692.000000  2.271667  61.833333  58.500000  8.431667  8.395000
# std     2742.281751  0.013292   0.531664   1.048809  0.044460  0.040373
# min    11226.000000  2.260000  61.100000  57.000000  8.370000  8.330000
# 25%    14270.750000  2.260000  61.450000  58.000000  8.407500  8.377500
# 50%    16547.000000  2.270000  62.000000  58.500000  8.435000  8.400000
# 75%    17835.500000  2.280000  62.100000  59.000000  8.447500  8.422500
# max    18055.000000  2.290000  62.500000  60.000000  8.500000  8.440000
#
#               z
# count  6.000000
# mean   5.203333
# std    0.039328
# min    5.150000
# 25%    5.175000
# 50%    5.210000
# 75%    5.230000
# max    5.250000

# %%
diamonds['x'][26192]=8.43
diamonds['y'][26192]=8.40
diamonds['z'][26192]=5.20

# or
'''
diamonds_num = diamonds_num.describe()
diamonds['x'][num]= diamonds_num[x][mean]
diamonds['y'][num]= diamonds_num[y][mean]
diamonds['z'][num]= diamonds_num[z][mean]

'''
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\4160087678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['x'][26192]=8.43
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\4160087678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['y'][26192]=8.40
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\4160087678.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#  19856	3142	1.00	59.1	59.0	6.55	6.48	0.00	Premium	G	SI2	Madrid
diamonds19856 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds19856 = diamonds19856.loc[diamonds19856['color'] == 'G']
diamonds19856 = diamonds19856.loc[diamonds19856['clarity'] == 'SI2']
diamonds19856 = diamonds19856.loc[diamonds19856['carat'] > 0.99]
diamonds19856 = diamonds19856.loc[diamonds19856['carat'] < 1.01]
diamonds19856 = diamonds19856.drop(19856)
diamonds19856.describe()
# Out:
#              price  carat      depth      table          x        y          z
# count    15.000000   15.0  15.000000  15.000000  15.000000  15.0000  15.000000
# mean   3903.333333    1.0  61.286667  58.933333   6.422000   6.3860   3.923333
# std     368.710236    0.0   1.324962   1.869556   0.085206   0.0751   0.052599
# min    3142.000000    1.0  59.000000  56.000000   6.290000   6.2500   3.830000
# 25%    3668.000000    1.0  60.450000  58.000000   6.360000   6.3300   3.895000
# 50%    3998.000000    1.0  61.800000  59.000000   6.430000   6.3900   3.930000
# 75%    4199.500000    1.0  62.000000  60.000000   6.495000   6.4550   3.970000
# max    4398.000000    1.0  63.000000  62.000000   6.550000   6.5000   4.000000

# %%
diamonds['z'][19856]=3.92
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\544953554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][19856]=3.92

# %%
#  14891	12631	2.18	59.4	61.0	8.49	8.45	0.00	Premium	H	SI2	Surat
diamonds14891 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds14891 = diamonds14891.loc[diamonds14891['color'] == 'H']
diamonds14891 = diamonds14891.loc[diamonds14891['clarity'] == 'SI2']
diamonds14891 = diamonds14891.loc[diamonds14891['carat'] > 2.17]
diamonds14891 = diamonds14891.loc[diamonds14891['carat'] < 2.21]
diamonds14891 = diamonds14891.drop(14891)
diamonds14891.describe()
# Out:
#               price     carat      depth      table         x         y  \
# count      5.000000  5.000000   5.000000   5.000000  5.000000  5.000000
# mean   16480.800000  2.194000  61.220000  58.600000  8.410000  8.346000
# std     2101.950451  0.008944   1.323631   0.894427  0.060415  0.074364
# min    12747.000000  2.180000  59.100000  58.000000  8.330000  8.270000
# 25%    16996.000000  2.190000  61.100000  58.000000  8.380000  8.280000
# 50%    17473.000000  2.200000  61.500000  58.000000  8.410000  8.350000
# 75%    17554.000000  2.200000  61.700000  59.000000  8.440000  8.380000
# max    17634.000000  2.200000  62.700000  60.000000  8.490000  8.450000
#
#               z
# count  5.000000
# mean   5.130000
# std    0.074162
# min    5.010000
# 25%    5.120000
# 50%    5.140000
# 75%    5.180000
# max    5.200000

# %%
diamonds['z'][14891]=5.13
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\2014947170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][14891]=5.13

# %%
#  34601	15397	2.25	61.3	58.0	8.52	8.42	0.00	Premium	I	SI1	Paris
diamonds34601 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds34601 = diamonds34601.loc[diamonds34601['color'] == 'I']
diamonds34601 = diamonds34601.loc[diamonds34601['clarity'] == 'SI1']
diamonds34601 = diamonds34601.loc[diamonds34601['carat'] > 2.20]
diamonds34601 = diamonds34601.loc[diamonds34601['carat'] < 2.27]
diamonds34601 = diamonds34601.drop(34601)
diamonds34601.describe()
# Out:
#               price     carat      depth      table         x        y  \
# count      4.000000  4.000000   4.000000   4.000000  4.000000  4.00000
# mean   17068.750000  2.225000  60.950000  59.000000  8.440000  8.39250
# std     2004.136951  0.017321   1.279323   0.816497  0.091287  0.09535
# min    14095.000000  2.210000  59.900000  58.000000  8.330000  8.28000
# 25%    16809.250000  2.217500  60.050000  58.750000  8.397500  8.34750
# 50%    17874.000000  2.220000  60.600000  59.000000  8.440000  8.39000
# 75%    18133.500000  2.227500  61.500000  59.250000  8.482500  8.43500
# max    18432.000000  2.250000  62.700000  60.000000  8.550000  8.51000
#
#              z
# count  4.00000
# mean   5.13000
# std    0.06532
# min    5.05000
# 25%    5.11000
# 50%    5.13000
# 75%    5.15000
# max    5.21000

# %%
diamonds['z'][34601]= 5.13
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1475790888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][34601]= 5.13

# %%
#  24795	3696	1.10	63.0	59.0	6.50	6.47	0.00	Premium	G	SI2	Dubai
diamonds26192 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds26192 = diamonds26192.loc[diamonds26192['color'] == 'G']
diamonds26192 = diamonds26192.loc[diamonds26192['clarity'] == 'SI2']
diamonds26192 = diamonds26192.loc[diamonds26192['carat'] > 1.09]
diamonds26192 = diamonds26192.loc[diamonds26192['carat'] < 1.12]
diamonds26192 = diamonds26192.drop(24795)
diamonds26192.describe()
# Out:
#              price  carat      depth      table         x         y         z
# count     5.000000   5.00   5.000000   5.000000  5.000000  5.000000  5.000000
# mean   4547.800000   1.11  61.800000  58.000000  6.640000  6.606000  4.092000
# std     417.422687   0.00   0.565685   0.707107  0.075166  0.071624  0.023875
# min    3804.000000   1.11  61.200000  57.000000  6.540000  6.490000  4.070000
# 25%    4670.000000   1.11  61.500000  58.000000  6.600000  6.600000  4.080000
# 50%    4755.000000   1.11  61.500000  58.000000  6.650000  6.610000  4.080000
# 75%    4755.000000   1.11  62.300000  58.000000  6.670000  6.660000  4.100000
# max    4755.000000   1.11  62.500000  59.000000  6.740000  6.670000  4.130000

# %%
diamonds['z'][24795]=4.09
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\232278303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][24795]=4.09

# %%
#  16425	17265	2.20	61.2	59.0	8.42	8.37	0.00	Premium	H	SI1	Surat
diamonds16425 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds16425 = diamonds16425.loc[diamonds16425['color'] == 'H']
diamonds16425 = diamonds16425.loc[diamonds16425['clarity'] == 'SI1']
diamonds16425 = diamonds16425.loc[diamonds16425['carat'] > 2.18]
diamonds16425 = diamonds16425.loc[diamonds16425['carat'] < 2.24]
diamonds16425
# Out:
#        price  carat  depth  table     x     y     z      cut color clarity  \
# 10342  17016   2.19   61.6   58.0  8.35  8.30  5.13  Premium     H     SI1
# 16425  17265   2.20   61.2   59.0  8.42  8.37  0.00  Premium     H     SI1
# 34048  15801   2.19   62.3   62.0  8.27  8.25  5.15  Premium     H     SI1
#
#             city
# 10342    Antwerp
# 16425      Surat
# 34048  Amsterdam

# %%
diamonds16425 = diamonds16425.drop(16425)
diamonds16425.describe()
# Out:
#               price  carat      depth      table         x         y         z
# count      2.000000   2.00   2.000000   2.000000  2.000000  2.000000  2.000000
# mean   16408.500000   2.19  61.950000  60.000000  8.310000  8.275000  5.140000
# std      859.134739   0.00   0.494975   2.828427  0.056569  0.035355  0.014142
# min    15801.000000   2.19  61.600000  58.000000  8.270000  8.250000  5.130000
# 25%    16104.750000   2.19  61.775000  59.000000  8.290000  8.262500  5.135000
# 50%    16408.500000   2.19  61.950000  60.000000  8.310000  8.275000  5.140000
# 75%    16712.250000   2.19  62.125000  61.000000  8.330000  8.287500  5.145000
# max    17016.000000   2.19  62.300000  62.000000  8.350000  8.300000  5.150000

# %%
diamonds['z'][16425]= 5.14
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3825032890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][16425]= 5.14

# %%
#  28029	2130	0.71	64.1	60.0	0.00	0.00	0.00	Good	F	SI2	Kimberly
diamonds28029 = diamonds.loc[diamonds['cut'] == 'Good']
diamonds28029 = diamonds28029.loc[diamonds28029['color'] == 'F']
diamonds28029 = diamonds28029.loc[diamonds28029['clarity'] == 'SI2']
diamonds28029 = diamonds28029.loc[diamonds28029['carat'] > 0.70]
diamonds28029 = diamonds28029.loc[diamonds28029['carat'] < 0.75]
diamonds28029
# Out:
#        price  carat  depth  table     x     y     z   cut color clarity  \
# 6465    2130   0.71   64.1   60.0  0.00  0.00  0.00  Good     F     SI2
# 7662    2072   0.71   63.6   60.0  5.64  5.61  3.58  Good     F     SI2
# 20419   2282   0.71   64.5   55.6  5.58  5.61  3.60  Good     F     SI2
# 22137   2685   0.74   62.6   65.0  5.66  5.69  3.55  Good     F     SI2
# 22879   2023   0.73   63.4   55.0  5.71  5.75  3.63  Good     F     SI2
# 28029   2130   0.71   64.1   60.0  0.00  0.00  0.00  Good     F     SI2
# 35493   2190   0.74   59.3   61.0  5.87  5.97  3.51  Good     F     SI2
#
#             city
# 6465      Madrid
# 7662   Amsterdam
# 20419     Zurich
# 22137    Antwerp
# 22879    Antwerp
# 28029   Kimberly
# 35493  Amsterdam

# %%
diamonds28029 = diamonds28029.drop(28029)
diamonds28029.describe()
# Out:
#              price     carat      depth      table         x         y  \
# count     6.000000  6.000000   6.000000   6.000000  6.000000  6.000000
# mean   2230.333333  0.723333  62.916667  59.433333  4.743333  4.771667
# std     240.475085  0.015055   1.886178   3.699550  2.325826  2.341405
# min    2023.000000  0.710000  59.300000  55.000000  0.000000  0.000000
# 25%    2086.500000  0.710000  62.800000  56.700000  5.595000  5.610000
# 50%    2160.000000  0.720000  63.500000  60.000000  5.650000  5.650000
# 75%    2259.000000  0.737500  63.975000  60.750000  5.697500  5.735000
# max    2685.000000  0.740000  64.500000  65.000000  5.870000  5.970000
#
#               z
# count  6.000000
# mean   2.978333
# std    1.459663
# min    0.000000
# 25%    3.520000
# 50%    3.565000
# 75%    3.595000
# max    3.630000

# %%
diamonds['x'][28029]=4.74
diamonds['y'][28029]=4.77
diamonds['z'][28029]=2.98
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\234720793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['x'][28029]=4.74
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\234720793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['y'][28029]=4.77
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\234720793.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][28029]=2.98

# %%
#  34423	6381	1.14	57.5	67.0	0.00	0.00	0.00	Fair	G	VS1	Antwerp
diamonds34423 = diamonds.loc[diamonds['cut'] == 'Fair']
diamonds34423 = diamonds34423.loc[diamonds34423['color'] == 'G']
diamonds34423 = diamonds34423.loc[diamonds34423['clarity'] == 'VS1']
diamonds34423 = diamonds34423.loc[diamonds34423['carat'] > 1.07]
diamonds34423 = diamonds34423.loc[diamonds34423['carat'] < 1.23]
diamonds34423
# Out:
#        price  carat  depth  table     x     y     z   cut color clarity  \
# 4652    5487   1.12   64.8   56.0  6.48  6.52  4.21  Fair     G     VS1
# 15144   7076   1.08   64.7   60.0  6.44  6.41  4.16  Fair     G     VS1
# 34423   6381   1.14   57.5   67.0  0.00  0.00  0.00  Fair     G     VS1
#
#           city
# 4652   Antwerp
# 15144   Zurich
# 34423  Antwerp

# %%
diamonds34423 = diamonds34423.drop(34423)
diamonds34423.describe()
# Out:
#              price     carat      depth      table         x         y  \
# count     2.000000  2.000000   2.000000   2.000000  2.000000  2.000000
# mean   6281.500000  1.100000  64.750000  58.000000  6.460000  6.465000
# std    1123.592675  0.028284   0.070711   2.828427  0.028284  0.077782
# min    5487.000000  1.080000  64.700000  56.000000  6.440000  6.410000
# 25%    5884.250000  1.090000  64.725000  57.000000  6.450000  6.437500
# 50%    6281.500000  1.100000  64.750000  58.000000  6.460000  6.465000
# 75%    6678.750000  1.110000  64.775000  59.000000  6.470000  6.492500
# max    7076.000000  1.120000  64.800000  60.000000  6.480000  6.520000
#
#               z
# count  2.000000
# mean   4.185000
# std    0.035355
# min    4.160000
# 25%    4.172500
# 50%    4.185000
# 75%    4.197500
# max    4.210000

# %%
diamonds['x'][34423]=6.46
diamonds['y'][34423]=6.47
diamonds['z'][34423]=4.19
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\610864990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['x'][34423]=6.46
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\610864990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['y'][34423]=6.47
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\610864990.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][34423]=4.19

# %%
#  6465	2130	0.71	64.1	60.0	0.00	0.00	0.00	Good	F	SI2	Madrid
diamonds6465 = diamonds.loc[diamonds['cut'] == 'Good']
diamonds6465 = diamonds6465.loc[diamonds6465['color'] == 'F']
diamonds6465 = diamonds6465.loc[diamonds6465['clarity'] == 'SI2']
diamonds6465 = diamonds6465.loc[diamonds6465['carat'] > 0.68]
diamonds6465 = diamonds6465.loc[diamonds6465['carat'] < 0.74]
diamonds6465
# Out:
#        price  carat  depth  table     x     y     z   cut color clarity  \
# 1035    1851   0.70   64.1   55.0  5.58  5.52  3.56  Good     F     SI2
# 6465    2130   0.71   64.1   60.0  0.00  0.00  0.00  Good     F     SI2
# 7662    2072   0.71   63.6   60.0  5.64  5.61  3.58  Good     F     SI2
# 9166    1806   0.70   63.6   56.0  5.63  5.56  3.56  Good     F     SI2
# 18989   2109   0.70   60.6   61.0  5.71  5.77  3.48  Good     F     SI2
# 20419   2282   0.71   64.5   55.6  5.58  5.61  3.60  Good     F     SI2
# 22879   2023   0.73   63.4   55.0  5.71  5.75  3.63  Good     F     SI2
# 28029   2130   0.71   64.1   60.0  4.74  4.77  2.98  Good     F     SI2
# 31855   2100   0.70   59.0   57.0  5.80  5.83  3.43  Good     F     SI2
# 33588   2062   0.70   62.2   59.0  5.62  5.64  3.50  Good     F     SI2
# 36775   1792   0.70   64.1   58.0  5.58  5.53  3.56  Good     F     SI2
# 40364   2411   0.70   64.1   59.0  5.58  5.53  3.56  Good     F     SI2
#
#              city
# ...

# %%
diamonds6465 = diamonds6465.drop(6465)
diamonds6465.describe()
# Out:
#              price      carat      depth      table          x          y  \
# count    11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   2058.000000   0.705455  63.027273  57.781818   5.560909   5.556364
# std     190.494094   0.009342   1.742464   2.173393   0.281334   0.281399
# min    1792.000000   0.700000  59.000000  55.000000   4.740000   4.770000
# 25%    1937.000000   0.700000  62.800000  55.800000   5.580000   5.530000
# 50%    2072.000000   0.700000  63.600000  58.000000   5.620000   5.610000
# 75%    2119.500000   0.710000  64.100000  59.500000   5.675000   5.695000
# max    2411.000000   0.730000  64.500000  61.000000   5.800000   5.830000
#
#                z
# count  11.000000
# mean    3.494545
# std     0.179742
# min     2.980000
# 25%     3.490000
# 50%     3.560000
# 75%     3.570000
# max     3.630000

# %%
diamonds['x'][6465]=5.56
diamonds['y'][6465]=5.56
diamonds['z'][6465]=3.49
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3890096932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['x'][6465]=5.56
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3890096932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['y'][6465]=5.56
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3890096932.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][6465]=3.49

# %%
#  3945	18207	2.02	62.7	53.0	8.02	7.95	0.00	Premium	H	VS2	Madrid
diamonds3945 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds3945 = diamonds3945.loc[diamonds3945['color'] == 'H']
diamonds3945 = diamonds3945.loc[diamonds3945['clarity'] == 'VS2']
diamonds3945 = diamonds3945.loc[diamonds3945['carat'] > 1.99]
diamonds3945 = diamonds3945.loc[diamonds3945['carat'] < 2.06]
diamonds3945
# Out:
#        price  carat  depth  table     x     y     z      cut color clarity  \
# 3945   18207   2.02   62.7   53.0  8.02  7.95  0.00  Premium     H     VS2
# 10715  17068   2.01   60.1   61.0  8.14  8.06  4.87  Premium     H     VS2
# 13097  15528   2.01   61.1   61.0  8.14  8.09  4.96  Premium     H     VS2
# 16838  17191   2.01   61.6   61.0  8.14  8.07  4.99  Premium     H     VS2
# 17506  15908   2.01   61.1   61.0  8.14  8.09  4.96  Premium     H     VS2
# 26108  18318   2.05   61.8   60.0  8.19  8.14  5.05  Premium     H     VS2
# 28928  18139   2.03   62.6   59.0  8.10  8.06  5.06  Premium     H     VS2
# 35491  15395   2.01   62.6   58.0  8.03  7.94  5.00  Premium     H     VS2
# 37758  16235   2.05   60.7   61.0  8.25  8.13  4.97  Premium     H     VS2
# 39424  18207   2.02   60.8   62.0  8.17  8.12  4.95  Premium     H     VS2
# 40144  17975   2.03   62.6   59.0  8.06  8.10  5.06  Premium     H     VS2
#
#             city
# 3945      Madrid
# 10715     Zurich
# ...

# %%
diamonds3945 = diamonds3945.drop(3945)
diamonds3945.describe()
# Out:
#               price      carat      depth      table          x          y  \
# count     10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   16996.400000   2.023000  61.500000  60.300000   8.136000   8.080000
# std     1154.863744   0.016364   0.890693   1.251666   0.062752   0.056569
# min    15395.000000   2.010000  60.100000  58.000000   8.030000   7.940000
# 25%    15989.750000   2.010000  60.875000  59.250000   8.110000   8.062500
# 50%    17129.500000   2.015000  61.350000  61.000000   8.140000   8.090000
# 75%    18098.000000   2.030000  62.400000  61.000000   8.162500   8.115000
# max    18318.000000   2.050000  62.600000  62.000000   8.250000   8.140000
#
#                z
# count  10.000000
# mean    4.987000
# std     0.059264
# min     4.870000
# 25%     4.960000
# 50%     4.980000
# 75%     5.037500
# max     5.060000

# %%
diamonds['z'][3945]=4.99
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\4016321661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][3945]=4.99

# %%
#  13839	18788	2.80	63.8	58.0	8.90	8.85	0.00	Good	G	SI2	Kimberly
diamonds13839 = diamonds.loc[diamonds['cut'] == 'Good']
#diamonds13839 = diamonds13839.loc[diamonds13839['color'] == 'G']
#diamonds13839 = diamonds13839.loc[diamonds13839['clarity'] == 'SI2']
diamonds13839 = diamonds13839.loc[diamonds13839['carat'] > 2.64]
diamonds13839 = diamonds13839.loc[diamonds13839['carat'] < 2.96]
diamonds13839
# Out:
#        price  carat  depth  table     x     y     z   cut color clarity  \
# 5988   16239   2.66   63.8   57.0  8.71  8.65  5.54  Good     H     SI2
# 13839  18788   2.80   63.8   58.0  8.90  8.85  0.00  Good     G     SI2
# 20676  16239   2.66   63.8   57.0  8.71  8.65  5.54  Good     H     SI2
# 30087  18686   2.67   63.8   58.0  8.69  8.64  5.54  Good     F     SI2
#
#            city
# 5988     Zurich
# 13839  Kimberly
# 20676     Surat
# 30087   Antwerp

# %%
diamonds13839 = diamonds13839.drop(13839)
diamonds13839.describe()
# Out:
#               price     carat         depth      table         x         y  \
# count      3.000000  3.000000  3.000000e+00   3.000000  3.000000  3.000000
# mean   17054.666667  2.663333  6.380000e+01  57.333333  8.703333  8.646667
# std     1412.776109  0.005774  8.702336e-15   0.577350  0.011547  0.005774
# min    16239.000000  2.660000  6.380000e+01  57.000000  8.690000  8.640000
# 25%    16239.000000  2.660000  6.380000e+01  57.000000  8.700000  8.645000
# 50%    16239.000000  2.660000  6.380000e+01  57.000000  8.710000  8.650000
# 75%    17462.500000  2.665000  6.380000e+01  57.500000  8.710000  8.650000
# max    18686.000000  2.670000  6.380000e+01  58.000000  8.710000  8.650000
#
#           z
# count  3.00
# mean   5.54
# std    0.00
# min    5.54
# 25%    5.54
# 50%    5.54
# 75%    5.54
# max    5.54

# %%
diamonds['z'][13839]=5.54
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\331193128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][13839]=5.54

# %%
#  34504	4731	1.50	64.0	61.0	7.15	7.04	0.00	Good	G	I1	Tel Aviv
diamonds34504 = diamonds.loc[diamonds['cut'] == 'Good']
diamonds34504 = diamonds34504.loc[diamonds34504['color'] == 'G']
diamonds34504 = diamonds34504.loc[diamonds34504['clarity'] == 'I1']
diamonds34504 = diamonds34504.loc[diamonds34504['carat'] > 1.45]
diamonds34504 = diamonds34504.loc[diamonds34504['carat'] < 1.55]
diamonds34504
# Out:
#        price  carat  depth  table     x     y     z   cut color clarity  \
# 1127    3179   1.50   57.4   62.0  7.56  7.39  4.29  Good     G      I1
# 6054    3497   1.51   64.0   59.0  7.29  7.17  4.63  Good     G      I1
# 34504   4731   1.50   64.0   61.0  7.15  7.04  0.00  Good     G      I1
#
#            city
# 1127   Kimberly
# 6054      Dubai
# 34504  Tel Aviv

# %%
diamonds34504 = diamonds34504.drop(34504)
diamonds34504.describe()
# Out:
#              price     carat      depth     table         x         y  \
# count     2.000000  2.000000   2.000000   2.00000  2.000000  2.000000
# mean   3338.000000  1.505000  60.700000  60.50000  7.425000  7.280000
# std     224.859956  0.007071   4.666905   2.12132  0.190919  0.155563
# min    3179.000000  1.500000  57.400000  59.00000  7.290000  7.170000
# 25%    3258.500000  1.502500  59.050000  59.75000  7.357500  7.225000
# 50%    3338.000000  1.505000  60.700000  60.50000  7.425000  7.280000
# 75%    3417.500000  1.507500  62.350000  61.25000  7.492500  7.335000
# max    3497.000000  1.510000  64.000000  62.00000  7.560000  7.390000
#
#               z
# count  2.000000
# mean   4.460000
# std    0.240416
# min    4.290000
# 25%    4.375000
# 50%    4.460000
# 75%    4.545000
# max    4.630000

# %%
diamonds['z'][34504]=4.46
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\506991115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][34504]=4.46

# %%
#  26978	3167	1.01	58.1	59.0	6.66	6.60	0.00	Premium	H	I1	London
diamonds26978 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds26978 = diamonds26978.loc[diamonds26978['color'] == 'H']
diamonds26978 = diamonds26978.loc[diamonds26978['clarity'] == 'I1']
diamonds26978 = diamonds26978.loc[diamonds26978['carat'] > 0.99]
diamonds26978 = diamonds26978.loc[diamonds26978['carat'] < 1.05]
diamonds26978
# Out:
#        price  carat  depth  table     x     y     z      cut color clarity  \
# 567     3199   1.02   62.5   60.0  6.41  6.39  4.00  Premium     H      I1
# 2781    1932   1.00   60.4   61.0  6.39  6.32  3.84  Premium     H      I1
# 11327   2695   1.00   61.3   60.0  6.39  6.43  3.93  Premium     H      I1
# 15417   2058   1.00   62.7   59.0  6.39  6.33  3.98  Premium     H      I1
# 19648   2206   1.01   58.4   60.0  6.53  6.48  3.80  Premium     H      I1
# 26978   3167   1.01   58.1   59.0  6.66  6.60  0.00  Premium     H      I1
# 28600   3141   1.02   62.5   60.0  6.39  6.41  4.00  Premium     H      I1
# 29606   2336   1.03   62.9   59.0  6.41  6.30  4.00  Premium     H      I1
#
#             city
# 567     Kimberly
# 2781   Las Vegas
# 11327      Surat
# 15417     Madrid
# 19648      Paris
# 26978     London
# 28600    Antwerp
# 29606      Surat

# %%
diamonds26978 = diamonds26978.drop(26978)
diamonds26978.describe()
# Out:
#              price     carat      depth      table         x         y  \
# count     7.000000  7.000000   7.000000   7.000000  7.000000  7.000000
# mean   2509.571429  1.011429  61.528571  59.857143  6.415714  6.380000
# std     511.237993  0.012150   1.645918   0.690066  0.051270  0.065828
# min    1932.000000  1.000000  58.400000  59.000000  6.390000  6.300000
# 25%    2132.000000  1.000000  60.850000  59.500000  6.390000  6.325000
# 50%    2336.000000  1.010000  62.500000  60.000000  6.390000  6.390000
# 75%    2918.000000  1.020000  62.600000  60.000000  6.410000  6.420000
# max    3199.000000  1.030000  62.900000  61.000000  6.530000  6.480000
#
#               z
# count  7.000000
# mean   3.935714
# std    0.083638
# min    3.800000
# 25%    3.885000
# 50%    3.980000
# 75%    4.000000
# max    4.000000

# %%
diamonds['z'][26978]=3.94
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1195273690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][26978]=3.94

# %%
#  21602	5564	1.15	59.2	56.0	6.88	6.83	0.00	Ideal	G	VS2	New York City
diamonds21602 = diamonds.loc[diamonds['cut'] == 'Ideal']
diamonds21602 = diamonds21602.loc[diamonds21602['color'] == 'G']
diamonds21602 = diamonds21602.loc[diamonds21602['clarity'] == 'VS2']
diamonds21602 = diamonds21602.loc[diamonds21602['carat'] > 1.13]
diamonds21602 = diamonds21602.loc[diamonds21602['carat'] < 1.17]
diamonds21602
# Out:
#        price  carat  depth  table     x     y     z    cut color clarity  \
# 6943    7587   1.15   61.6   55.0  6.74  6.76  4.16  Ideal     G     VS2
# 7180    7667   1.14   61.4   56.0  6.74  6.77  4.15  Ideal     G     VS2
# 7581    7113   1.16   61.7   57.0  6.72  6.80  4.17  Ideal     G     VS2
# 8589    7128   1.16   60.7   58.0  6.86  6.81  4.15  Ideal     G     VS2
# 12265   7171   1.14   61.5   57.0  6.72  6.68  4.12  Ideal     G     VS2
# 14050   5008   1.15   62.2   54.0  6.74  6.65  4.17  Ideal     G     VS2
# 17139   7371   1.14   62.0   55.0  6.68  6.77  4.17  Ideal     G     VS2
# 21602   5564   1.15   59.2   56.0  6.88  6.83  0.00  Ideal     G     VS2
# 22800   7042   1.14   61.5   57.0  6.68  6.72  4.12  Ideal     G     VS2
# 30781   7074   1.16   62.3   57.0  6.66  6.72  4.17  Ideal     G     VS2
# 32797   7099   1.14   60.5   60.0  6.77  6.75  4.09  Ideal     G     VS2
# 32944   7451   1.16   62.5   56.0  6.67  6.73  4.19  Ideal     G     VS2
# ...

# %%
diamonds21602 = diamonds21602.drop(21602)
diamonds21602.describe()
# Out:
#              price      carat      depth      table          x          y  \
# count    12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean   7075.833333   1.148333  61.650000  56.500000   6.722500   6.739167
# std     683.878755   0.009374   0.600757   1.566699   0.055124   0.046993
# min    5008.000000   1.140000  60.500000  54.000000   6.660000   6.650000
# 25%    7092.750000   1.140000  61.475000  55.750000   6.680000   6.717500
# 50%    7149.500000   1.145000  61.650000  56.500000   6.720000   6.740000
# 75%    7391.000000   1.160000  62.050000  57.000000   6.740000   6.770000
# max    7667.000000   1.160000  62.500000  60.000000   6.860000   6.810000
#
#                z
# count  12.000000
# mean    4.150000
# std     0.028284
# min     4.090000
# 25%     4.135000
# 50%     4.155000
# 75%     4.170000
# max     4.190000

# %%
diamonds['z'][21602]=4.15
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3370967769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][21602]=4.15

# %%
#  1606	3837	1.01	59.2	58.0	6.50	6.47	0.00	Premium	F	SI2	New York City
diamonds1606 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds1606 = diamonds1606.loc[diamonds1606['color'] == 'F']
diamonds1606 = diamonds1606.loc[diamonds1606['clarity'] == 'SI2']
diamonds1606 = diamonds1606.loc[diamonds1606['carat'] > 1.00]
diamonds1606 = diamonds1606.loc[diamonds1606['carat'] < 1.02]
diamonds1606
# Out:
#        price  carat  depth  table     x     y     z      cut color clarity  \
# 294     4616   1.01   62.9   59.0  6.32  6.27  3.96  Premium     F     SI2
# 1606    3837   1.01   59.2   58.0  6.50  6.47  0.00  Premium     F     SI2
# 2227    4796   1.01   62.2   57.0  6.43  6.36  3.98  Premium     F     SI2
# 3269    4416   1.01   62.2   59.0  6.41  6.45  4.00  Premium     F     SI2
# 3563    4468   1.01   62.6   54.0  6.38  6.34  3.98  Premium     F     SI2
# 5940    4416   1.01   61.3   60.0  6.40  6.43  3.93  Premium     F     SI2
# 6175    4497   1.01   62.8   60.0  6.40  6.33  4.00  Premium     F     SI2
# 6243    4416   1.01   62.2   59.0  6.38  6.42  3.98  Premium     F     SI2
# 6932    3733   1.01   62.7   58.0  6.38  6.32  3.98  Premium     F     SI2
# 6961    4497   1.01   62.7   59.0  6.40  6.35  4.00  Premium     F     SI2
# 7068    4197   1.01   58.8   62.0  6.49  6.46  3.81  Premium     F     SI2
# ...

# %%
diamonds1606 = diamonds1606.drop(1606)
diamonds1606.describe()
# Out:
#              price         carat      depth      table          x          y  \
# count    38.000000  3.800000e+01  38.000000  38.000000  38.000000  38.000000
# mean   4240.578947  1.010000e+00  61.631579  58.868421   6.427632   6.390263
# std     403.186338  2.250252e-16   1.098920   1.695320   0.062187   0.058378
# min    3297.000000  1.010000e+00  58.800000  54.000000   6.320000   6.270000
# 25%    4010.250000  1.010000e+00  61.150000  58.000000   6.390000   6.350000
# 50%    4416.000000  1.010000e+00  61.850000  59.000000   6.410000   6.395000
# 75%    4497.000000  1.010000e+00  62.475000  60.000000   6.460000   6.430000
# max    5096.000000  1.010000e+00  63.000000  62.000000   6.610000   6.520000
#
#                z
# count  38.000000
# mean    3.950000
# std     0.047077
# min     3.810000
# 25%     3.930000
# 50%     3.960000
# 75%     3.980000
# max     4.010000

# %%
diamonds['z'][1606]=3.95
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3781607426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][1606]=3.95

# %%
#  14815	4954	1.07	61.6	56.0	0.00	6.62	0.00	Ideal	F	SI2	Kimberly
diamonds14815 = diamonds.loc[diamonds['cut'] == 'Ideal']
diamonds14815 = diamonds14815.loc[diamonds14815['color'] == 'F']
diamonds14815 = diamonds14815.loc[diamonds14815['clarity'] == 'SI2']
diamonds14815 = diamonds14815.loc[diamonds14815['carat'] > 1.05]
diamonds14815 = diamonds14815.loc[diamonds14815['carat'] < 1.09]
diamonds14815
# Out:
#        price  carat  depth  table     x     y     z    cut color clarity  \
# 2825    4374   1.07   61.9   55.0  6.53  6.58  4.06  Ideal     F     SI2
# 2926    5240   1.07   61.5   55.0  6.56  6.62  4.05  Ideal     F     SI2
# 4738    4678   1.07   61.5   57.0  6.57  6.60  4.05  Ideal     F     SI2
# 5722    4568   1.06   60.7   57.0  6.57  6.61  4.00  Ideal     F     SI2
# 14310   5405   1.07   61.6   57.0  6.56  6.53  4.03  Ideal     F     SI2
# 14815   4954   1.07   61.6   56.0  0.00  6.62  0.00  Ideal     F     SI2
# 17758   3461   1.06   62.7   56.0  6.52  6.47  4.07  Ideal     F     SI2
# 20309   4764   1.07   61.5   57.0  6.60  6.57  4.05  Ideal     F     SI2
# 23289   4678   1.07   62.0   57.0  6.49  6.60  4.06  Ideal     F     SI2
# 31005   5027   1.07   60.7   56.9  6.62  6.65  4.02  Ideal     F     SI2
# 35592   4764   1.07   62.0   57.0  6.60  6.49  4.06  Ideal     F     SI2
# 37662   4128   1.07   61.2   57.0  6.62  6.59  4.04  Ideal     F     SI2
#
#              city
# ...

# %%
diamonds14815 = diamonds14815.drop(14815)
diamonds14815.describe()
# Out:
#              price      carat      depth      table          x          y  \
# count    11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   4644.272727   1.068182  61.572727  56.536364   6.567273   6.573636
# std     534.467790   0.004045   0.584963   0.815197   0.041735   0.055367
# min    3461.000000   1.060000  60.700000  55.000000   6.490000   6.470000
# 25%    4471.000000   1.070000  61.350000  56.450000   6.545000   6.550000
# 50%    4678.000000   1.070000  61.500000  57.000000   6.570000   6.590000
# 75%    4895.500000   1.070000  61.950000  57.000000   6.600000   6.605000
# max    5405.000000   1.070000  62.700000  57.000000   6.620000   6.650000
#
#                z
# count  11.000000
# mean    4.044545
# std     0.020671
# min     4.000000
# 25%     4.035000
# 50%     4.050000
# 75%     4.060000
# max     4.070000

# %%
diamonds['x'][14815]=6.57
diamonds['z'][14815]=4.04
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3401534906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['x'][14815]=6.57
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\3401534906.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][14815]=4.04

# %%
diamonds.sort_values(by = 'x')
# Out:
#        price  carat  depth  table      x      y     z        cut color  \
# 5157     367   0.20   61.7   60.0   3.77   3.72  2.31    Premium     D
# 6423     367   0.20   59.8   62.0   3.79   3.77  2.26    Premium     E
# 1582     345   0.20   60.2   62.0   3.79   3.75  2.27    Premium     E
# 23007    367   0.20   61.5   57.0   3.81   3.77  2.33      Ideal     D
# 8984     386   0.21   63.2   54.0   3.82   3.78  2.40  Very Good     E
# ...      ...    ...    ...    ...    ...    ...   ...        ...   ...
# 27893  17329   4.13   64.8   61.0  10.00   9.85  6.43       Fair     H
# 2884   15984   4.00   63.3   58.0  10.01   9.94  6.31  Very Good     I
# 23609  15223   4.01   62.5   62.0  10.02   9.94  6.24    Premium     J
# 3468   15223   4.01   61.0   61.0  10.14  10.10  6.17    Premium     I
# 31083  18531   4.50   65.8   58.0  10.23  10.16  6.72       Fair     J
#
#       clarity           city
# 5157      VS2          Surat
# 6423      VS2     Luxembourg
# ...

# %%
#  14708	12210	2.00	58.9	57.0	8.09	58.90	8.06	Premium	H	SI2	Paris
diamonds14708 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds14708 = diamonds14708.loc[diamonds14708['color'] == 'H']
diamonds14708 = diamonds14708.loc[diamonds14708['clarity'] == 'SI2']
diamonds14708 = diamonds14708.loc[diamonds14708['carat'] > 1.99]
diamonds14708 = diamonds14708.loc[diamonds14708['carat'] < 2.01]
diamonds14708
# Out:
#        price  carat  depth  table     x      y     z      cut color clarity  \
# 10315  13134    2.0   61.5   61.0  8.13   8.10  4.99  Premium     H     SI2
# 11140  15312    2.0   60.7   60.0  8.07   8.11  4.91  Premium     H     SI2
# 14708  12210    2.0   58.9   57.0  8.09  58.90  8.06  Premium     H     SI2
# 15812  16031    2.0   62.8   56.0  8.04   7.98  5.03  Premium     H     SI2
# 16745  11975    2.0   62.8   57.0  8.05   8.01  5.04  Premium     H     SI2
# 21089  15451    2.0   60.7   60.0  8.11   8.07  4.91  Premium     H     SI2
# 22444  15451    2.0   59.7   61.0  8.20   8.15  4.88  Premium     H     SI2
# 23526  11108    2.0   61.4   59.0  8.07   8.00  4.93  Premium     H     SI2
# 35790  11202    2.0   62.1   60.0  8.10   8.01  5.30  Premium     H     SI2
# 39317  12940    2.0   62.5   58.0  8.14   8.03  5.05  Premium     H     SI2
#
#              city
# 10315      Zurich
# 11140      Madrid
# 14708       Paris
# 15812       Dubai
# 16745    Tel Aviv
# ...

# %%
diamonds14708 = diamonds14708.drop(14708)
diamonds14708.describe()
# Out:
#               price  carat      depth      table         x         y         z
# count      9.000000    9.0   9.000000   9.000000  9.000000  9.000000  9.000000
# mean   13622.666667    2.0  61.577778  59.111111  8.101111  8.051111  5.004444
# std     1966.670155    0.0   1.073287   1.763834  0.050607  0.058618  0.127682
# min    11108.000000    2.0  59.700000  56.000000  8.040000  7.980000  4.880000
# 25%    11975.000000    2.0  60.700000  58.000000  8.070000  8.010000  4.910000
# 50%    13134.000000    2.0  61.500000  60.000000  8.100000  8.030000  4.990000
# 75%    15451.000000    2.0  62.500000  60.000000  8.130000  8.100000  5.040000
# max    16031.000000    2.0  62.800000  61.000000  8.200000  8.150000  5.300000

# %%
diamonds['y'][14708]=8.06 # z to y
diamonds['z'][14708]=5.00 # here the mean
# Out:
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\365541591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['y'][14708]=8.06 # z to y
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\365541591.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds['z'][14708]=5.00 # here the mean

# %%
diamonds
# Out:
#        price  carat  depth  table     x     y     z        cut color clarity  \
# 0       4268   1.21   62.4   58.0  6.83  6.79  4.25    Premium     J     VS2
# 1        505   0.32   63.0   57.0  4.35  4.38  2.75  Very Good     H     VS2
# 2       2686   0.71   65.5   55.0  5.62  5.53  3.65       Fair     G     VS1
# 3        738   0.41   63.8   56.0  4.68  4.72  3.00       Good     D     SI1
# 4       4882   1.02   60.5   59.0  6.55  6.51  3.95      Ideal     G     SI1
# ...      ...    ...    ...    ...   ...   ...   ...        ...   ...     ...
# 40450  10070   1.34   62.7   57.0  7.10  7.04  4.43      Ideal     G     VS1
# 40451  12615   2.02   57.1   60.0  8.31  8.25  4.73       Good     F     SI2
# 40452   5457   1.01   62.7   56.0  6.37  6.42  4.01      Ideal     H     SI1
# 40453    456   0.33   61.9   54.3  4.45  4.47  2.76      Ideal     J     VS1
# 40454   6232   1.24   62.0   58.0  6.83  6.88  4.25      Ideal     I     SI1
#
#             city
# 0          Dubai
# ...

# %%
diamonds.to_csv('../../../001data/003preprocessing/001missing_values/diamonds_train.csv')

# %% [markdown]
# ---

# %% [markdown]
# ### Diamonds test

# %%
diamonds_test = pd.read_csv('../../../001data/001adquisition/diamonds_test.csv')

# %%
diamonds_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13485 entries, 0 to 13484
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       13485 non-null  int64
#  1   carat    13485 non-null  float64
#  2   cut      13485 non-null  object
#  3   color    13485 non-null  object
#  4   clarity  13485 non-null  object
#  5   depth    13485 non-null  float64
#  6   table    13485 non-null  float64
#  7   x        13485 non-null  float64
#  8   y        13485 non-null  float64
#  9   z        13485 non-null  float64
#  10  city     13485 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
# 6685	6685	1.00	Very Good	H	VS2	63.3	53.0	0.00	0.00	0.00	Paris
diamonds_test6685 = diamonds.loc[diamonds['cut'] == 'Very Good']
diamonds_test6685 = diamonds_test6685.loc[diamonds_test6685['color'] == 'H']
diamonds_test6685 = diamonds_test6685.loc[diamonds_test6685['clarity'] == 'VS2']
diamonds_test6685 = diamonds_test6685.loc[diamonds_test6685['carat'] > 0.99]
diamonds_test6685 = diamonds_test6685.loc[diamonds_test6685['carat'] < 1.01]
diamonds_test6685 = diamonds_test6685.describe()
diamonds_test6685
# Out:
#              price  carat      depth      table         x         y     z
# count     9.000000    9.0   9.000000   9.000000  9.000000  9.000000  9.00
# mean   5114.000000    1.0  62.088889  58.777778  6.395556  6.391111  3.97
# std     469.982181    0.0   1.814142   3.073181  0.105132  0.120358  0.06
# min    4514.000000    1.0  59.600000  53.000000  6.230000  6.220000  3.88
# 25%    4978.000000    1.0  60.700000  57.000000  6.310000  6.290000  3.92
# 50%    5000.000000    1.0  62.900000  59.000000  6.380000  6.370000  3.97
# 75%    5121.000000    1.0  63.300000  60.000000  6.470000  6.490000  4.01
# max    5883.000000    1.0  64.700000  63.000000  6.550000  6.570000  4.05

# %%
diamonds_test['x'][6685]=diamonds_test6685['x']['mean']
print(diamonds_test['x'][6685])
diamonds_test['y'][6685]=diamonds_test6685['y']['mean']
print(diamonds_test['y'][6685])
diamonds_test['z'][6685]=diamonds_test6685['z']['mean']
print(diamonds_test['z'][6685])
# Out:
# 6.395555555555556
# 6.391111111111112
# 3.9700000000000006
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1315723032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['x'][6685]=diamonds_test6685['x']['mean']
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1315723032.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['y'][6685]=diamonds_test6685['y']['mean']
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1315723032.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 2901	2901	1.20	Premium	D	VVS1	62.1	59.0	0.00	0.00	0.00	Tel Aviv
diamonds_test2901 = diamonds.loc[diamonds['cut'] == 'Very Good']
diamonds_test2901 = diamonds_test2901.loc[diamonds_test2901['color'] == 'H']
diamonds_test2901 = diamonds_test2901.loc[diamonds_test2901['clarity'] == 'VS2']
diamonds_test2901 = diamonds_test2901.loc[diamonds_test2901['carat'] > 0.99]
diamonds_test2901 = diamonds_test2901.loc[diamonds_test2901['carat'] < 1.01]
diamonds_test2901 = diamonds_test2901.describe()
diamonds_test2901
# Out:
#              price  carat      depth      table         x         y     z
# count     9.000000    9.0   9.000000   9.000000  9.000000  9.000000  9.00
# mean   5114.000000    1.0  62.088889  58.777778  6.395556  6.391111  3.97
# std     469.982181    0.0   1.814142   3.073181  0.105132  0.120358  0.06
# min    4514.000000    1.0  59.600000  53.000000  6.230000  6.220000  3.88
# 25%    4978.000000    1.0  60.700000  57.000000  6.310000  6.290000  3.92
# 50%    5000.000000    1.0  62.900000  59.000000  6.380000  6.370000  3.97
# 75%    5121.000000    1.0  63.300000  60.000000  6.470000  6.490000  4.01
# max    5883.000000    1.0  64.700000  63.000000  6.550000  6.570000  4.05

# %%
diamonds_test.sort_values(by='x')
# Out:
#           id  carat        cut color clarity  depth  table      x      y  \
# 7488    7488   1.56      Ideal     G     VS2   62.2   54.0   0.00   0.00
# 2901    2901   1.20    Premium     D    VVS1   62.1   59.0   0.00   0.00
# 10562  10562   0.20    Premium     F     VS2   62.6   59.0   3.73   3.71
# 7976    7976   0.20    Premium     D     VS2   62.3   60.0   3.73   3.68
# 12241  12241   0.20  Very Good     E     VS2   63.4   59.0   3.74   3.71
# ...      ...    ...        ...   ...     ...    ...    ...    ...    ...
# 8355    8355   3.01    Premium     J     SI2   60.7   59.0   9.35   9.22
# 6399    6399   3.00    Premium     G      I1   59.7   60.0   9.42   9.26
# 9838    9838   3.65       Fair     H      I1   67.1   53.0   9.53   9.48
# 12305  12305   3.67    Premium     I      I1   62.4   56.0   9.86   9.81
# 94        94   5.01       Fair     J      I1   65.5   59.0  10.74  10.54
#
#           z        city
# 7488   0.00      Madrid
# 2901   0.00    Tel Aviv
# ...

# %%
diamonds_test['x'][2901]=diamonds_test2901['x']['mean']
print(diamonds_test['x'][2901])
diamonds_test['y'][2901]=diamonds_test2901['y']['mean']
print(diamonds_test['y'][2901])
diamonds_test['z'][2901]=diamonds_test2901['z']['mean']
print(diamonds_test['z'][2901])
# Out:
# 6.395555555555556
# 6.391111111111112
# 3.9700000000000006
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\643032296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['x'][2901]=diamonds_test2901['x']['mean']
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\643032296.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['y'][2901]=diamonds_test2901['y']['mean']
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\643032296.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 7488	7488	1.56	Ideal	G	VS2	62.2	54.0	0.00	0.00	0.00	Madrid
diamonds_test7488 = diamonds.loc[diamonds['cut'] == 'Ideal']
diamonds_test7488 = diamonds_test7488.loc[diamonds_test7488['color'] == 'G']
diamonds_test7488 = diamonds_test7488.loc[diamonds_test7488['clarity'] == 'VS2']
diamonds_test7488 = diamonds_test7488.loc[diamonds_test7488['carat'] > 1.52]
diamonds_test7488 = diamonds_test7488.loc[diamonds_test7488['carat'] < 1.60]
diamonds_test7488 = diamonds_test7488.describe()
diamonds_test7488
# Out:
#               price      carat      depth      table          x          y  \
# count     11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   13080.727273   1.547273  61.618182  56.418182   7.439091   7.448182
# std     1468.889723   0.017939   0.749424   1.150494   0.042061   0.058450
# min     9794.000000   1.530000  60.200000  55.000000   7.350000   7.300000
# 25%    12706.500000   1.540000  61.350000  55.800000   7.425000   7.435000
# 50%    13369.000000   1.540000  61.600000  56.000000   7.440000   7.460000
# 75%    13853.000000   1.550000  61.900000  57.000000   7.460000   7.485000
# max    15395.000000   1.590000  62.800000  59.000000   7.510000   7.520000
#
#                z
# count  11.000000
# mean    4.583636
# std     0.050254
# min     4.510000
# 25%     4.545000
# 50%     4.590000
# 75%     4.610000
# max     4.680000

# %%
diamonds_test['x'][7488]=diamonds_test7488['x']['mean']
print(diamonds_test['x'][7488])
diamonds_test['y'][7488]=diamonds_test7488['y']['mean']
print(diamonds_test['y'][7488])
diamonds_test['z'][7488]=diamonds_test7488['z']['mean']
print(diamonds_test['z'][7488])
# Out:
# 7.4390909090909085
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\824123346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['x'][7488]=diamonds_test7488['x']['mean']
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\824123346.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['y'][7488]=diamonds_test7488['y']['mean']
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\824123346.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 5465	5465	1.12	Premium	G	I1	60.4	59.0	6.71	6.67	0.00	London
diamonds_test5465 = diamonds.loc[diamonds['cut'] == 'Premium']
diamonds_test5465 = diamonds_test5465.loc[diamonds_test5465['color'] == 'G']
diamonds_test5465 = diamonds_test5465.loc[diamonds_test5465['clarity'] == 'I1']
diamonds_test5465 = diamonds_test5465.loc[diamonds_test5465['carat'] > 1.04]
diamonds_test5465 = diamonds_test5465.loc[diamonds_test5465['carat'] < 1.21]
diamonds_test5465 = diamonds_test5465.describe()
diamonds_test5465
# Out:
#              price     carat      depth  table         x         y         z
# count     4.000000  4.000000   4.000000   4.00  4.000000  4.000000  4.000000
# mean   3197.250000  1.132500  61.100000  58.25  6.742500  6.660000  4.092500
# std     612.515782  0.062383   0.583095   0.50  0.110265  0.134907  0.051235
# min    2378.000000  1.050000  60.300000  58.00  6.580000  6.470000  4.020000
# 25%    2912.750000  1.110000  60.975000  58.00  6.722500  6.612500  4.080000
# 50%    3332.500000  1.140000  61.200000  58.00  6.785000  6.700000  4.105000
# 75%    3617.000000  1.162500  61.325000  58.25  6.805000  6.747500  4.117500
# max    3746.000000  1.200000  61.700000  59.00  6.820000  6.770000  4.140000

# %%
diamonds_test['z'][5465]=diamonds_test6685['z']['mean']
print(diamonds_test['z'][5465])
# Out:
# 3.9700000000000006
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\4146442449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['z'][5465]=diamonds_test6685['z']['mean']

# %%
# 7336	7336	0.51	Very Good	E	VS1	61.8	54.7	5.12	5.15	31.80	Surat
diamonds_test['z'][7336]=3.18
print(diamonds_test['z'][7336])
# Out:
# 3.18
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\301187294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['z'][7336]=3.18

# %%
# 1665	1665	0.51	Ideal	E	VS1	61.8	55.0	5.15	31.80	5.12	New York City
diamonds_test['y'][1665]=5.12
print(diamonds_test['y'][1665])
diamonds_test['z'][1665]=3.18
print(diamonds_test['z'][1665])
# Out:
# 5.12
# 3.18
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1380116623.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['y'][1665]=5.12
# C:\Users\marym\AppData\Local\Temp\ipykernel_11180\1380116623.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_test['z'][1665]=3.18

# %%
diamonds_test.sort_values(by = 'table')
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 11951  11951   0.67       Good     I    VVS2   58.9   51.0  5.74  5.78  3.40
# 11459  11459   2.00  Very Good     J     VS1   61.0   51.6  8.14  8.18  4.97
# 3914    3914   0.51    Premium     G     VS1   62.0   52.0  5.37  5.05  3.23
# 4144    4144   0.60    Premium     D     SI1   61.5   52.0  5.50  5.43  3.36
# 3309    3309   0.61      Ideal     G      IF   61.8   52.0  5.46  5.55  3.40
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 1847    1847   2.10       Fair     F     SI2   59.5   69.0  8.35  8.25  4.94
# 4461    4461   0.72       Fair     F     VS1   56.9   69.0  5.93  5.77  3.33
# 7980    7980   0.82       Fair     F     SI2   56.7   70.0  6.28  6.16  3.53
# 5511    5511   0.68       Fair     G     SI1   58.0   71.0  5.85  5.70  3.35
# 6258    6258   0.50       Fair     E     VS2   79.0   73.0  5.21  5.18  4.09
#
#                 city
# 11951          Paris
# ...

# %%
diamonds_test.to_csv('../../../001data/003preprocessing/001missing_values/diamonds_test.csv')
